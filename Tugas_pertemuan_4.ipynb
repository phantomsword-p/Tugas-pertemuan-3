# %% [markdown]
# # Import library

# %%
# Mengimpor library yang diperlukan
import pandas as pd  # Digunakan untuk manipulasi data dan analisis
import numpy as np  # Digunakan untuk operasi numerik
import requests  # Digunakan untuk mengambil data dari URL
import matplotlib.pyplot as plt  # Digunakan untuk visualisasi data
import seaborn as sns  # Digunakan untuk visualisasi data yang lebih estetis

# %% [markdown]
# # Unduh data

# %%
import zipfile
import os
import pandas as pd
import requests
from io import BytesIO

# URL untuk file ZIP
urls = [
    "http://data.gdeltproject.org/gdeltv2/20150219183000.mentions.CSV.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219183000.gkg.csv.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219184500.export.CSV.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219184500.mentions.CSV.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219184500.gkg.csv.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219190000.export.CSV.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219190000.mentions.CSV.zip"
]

# Fungsi untuk mengunduh dan mengekstrak file ZIP
def download_and_extract_zip(url):
    print(f"Downloading {url}")
    # Mengunduh file ZIP dari URL
    response = requests.get(url)
    zipfile_content = BytesIO(response.content)

    # Mengekstrak file ZIP
    with zipfile.ZipFile(zipfile_content) as zip_ref:
        # Mendapatkan daftar file dalam ZIP
        file_names = zip_ref.namelist()
        # Mengambil file CSV pertama (asumsi hanya ada satu file CSV di dalam ZIP)
        csv_file = file_names[0]

        # Membaca file CSV langsung dari ZIP dengan parameter error_bad_lines=False
        with zip_ref.open(csv_file) as my_file:
            try:
                # Coba membaca CSV dengan parameter yang lebih fleksibel
                return pd.read_csv(my_file, error_bad_lines=False, warn_bad_lines=True)
            except Exception as e:
                print(f"Error reading {csv_file}: {e}")
                return pd.DataFrame()  # Mengembalikan DataFrame kosong jika ada error

# Mengunduh dan menggabungkan data dari semua URL
all_data = pd.DataFrame()

for url in urls:
    data = download_and_extract_zip(url)
    if not data.empty:  # Pastikan data tidak kosong sebelum digabungkan
        all_data = pd.concat([all_data, data], ignore_index=True)

# Menampilkan 5 data pertama dari gabungan data
print("Data gabungan:")
print(all_data.head())

# Menyimpan data gabungan ke file CSV
all_data.to_csv('gdelt_combined_data.csv', index=False)
print("\nData telah disimpan sebagai 'gdelt_combined_data.csv'")
# Out:
# Downloading http://data.gdeltproject.org/gdeltv2/20150219183000.mentions.CSV.zip
# Error reading 20150219183000.mentions.CSV: read_csv() got an unexpected keyword argument 'error_bad_lines'
# Downloading http://data.gdeltproject.org/gdeltv2/20150219183000.gkg.csv.zip
# Error reading 20150219183000.gkg.csv: read_csv() got an unexpected keyword argument 'error_bad_lines'
# Downloading http://data.gdeltproject.org/gdeltv2/20150219184500.export.CSV.zip
# Error reading 20150219184500.export.CSV: read_csv() got an unexpected keyword argument 'error_bad_lines'
# Downloading http://data.gdeltproject.org/gdeltv2/20150219184500.mentions.CSV.zip
# Error reading 20150219184500.mentions.CSV: read_csv() got an unexpected keyword argument 'error_bad_lines'
# Downloading http://data.gdeltproject.org/gdeltv2/20150219184500.gkg.csv.zip
# Error reading 20150219184500.gkg.csv: read_csv() got an unexpected keyword argument 'error_bad_lines'
# Downloading http://data.gdeltproject.org/gdeltv2/20150219190000.export.CSV.zip
# Error reading 20150219190000.export.CSV: read_csv() got an unexpected keyword argument 'error_bad_lines'
# Downloading http://data.gdeltproject.org/gdeltv2/20150219190000.mentions.CSV.zip
# Error reading 20150219190000.mentions.CSV: read_csv() got an unexpected keyword argument 'error_bad_lines'
# Data gabungan:
# Empty DataFrame
# Columns: []
# Index: []
#
# Data telah disimpan sebagai 'gdelt_combined_data.csv'

# %%
import zipfile
import os
import pandas as pd
import requests
from io import BytesIO

# URL untuk file ZIP
urls = [
    "http://data.gdeltproject.org/gdeltv2/20150219183000.mentions.CSV.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219183000.gkg.csv.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219184500.export.CSV.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219184500.mentions.CSV.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219184500.gkg.csv.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219190000.export.CSV.zip",
    "http://data.gdeltproject.org/gdeltv2/20150219190000.mentions.CSV.zip"
]

# Fungsi untuk mengunduh dan mengekstrak file ZIP
def download_and_extract_zip(url):
    print(f"Downloading {url}")
    # Mengunduh file ZIP dari URL
    response = requests.get(url)
    zipfile_content = BytesIO(response.content)

    # Mengekstrak file ZIP
    with zipfile.ZipFile(zipfile_content) as zip_ref:
        # Mendapatkan daftar file dalam ZIP
        file_names = zip_ref.namelist()
        # Mengambil file CSV pertama (asumsi hanya ada satu file CSV di dalam ZIP)
        csv_file = file_names[0]

        # Membaca file CSV langsung dari ZIP dengan parameter on_bad_lines='skip' dan sep='\t'
        with zip_ref.open(csv_file) as my_file:
            try:
                # Membaca CSV dengan tab sebagai pemisah
                return pd.read_csv(my_file, sep='\t', on_bad_lines='skip')  # Menggunakan sep='\t' untuk tab separator
            except Exception as e:
                print(f"Error reading {csv_file}: {e}")
                return pd.DataFrame()  # Mengembalikan DataFrame kosong jika ada error

# Mengunduh dan menggabungkan data dari semua URL
all_data = pd.DataFrame()

# %%
for url in urls:
    data = download_and_extract_zip(url)
    if not data.empty:  # Pastikan data tidak kosong sebelum digabungkan
        all_data = pd.concat([all_data, data], ignore_index=True)

# Menampilkan 5 data pertama dari gabungan data
print("Data gabungan:")
print(all_data.head())

# Menyimpan data gabungan ke file CSV
all_data.to_csv('gdelt_combined_data.csv', index=False)
print("\nData telah disimpan sebagai 'gdelt_combined_Data.csv'")
# Out:
# Downloading http://data.gdeltproject.org/gdeltv2/20150219183000.mentions.CSV.zip
# Downloading http://data.gdeltproject.org/gdeltv2/20150219183000.gkg.csv.zip
# Downloading http://data.gdeltproject.org/gdeltv2/20150219184500.export.CSV.zip
# Downloading http://data.gdeltproject.org/gdeltv2/20150219184500.mentions.CSV.zip
# Downloading http://data.gdeltproject.org/gdeltv2/20150219184500.gkg.csv.zip
# Downloading http://data.gdeltproject.org/gdeltv2/20150219190000.export.CSV.zip
# Downloading http://data.gdeltproject.org/gdeltv2/20150219190000.mentions.CSV.zip
# Data gabungan:
#      410656065  20150219174500  20150219183000    1  wickedlocal.com  \
# 0  410656066.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
# 1  410656067.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
# 2  410656068.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
# 3  410656069.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
# 4  410656070.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
#
#   http://boxborough.wickedlocal.com/article/20150219/NEWS/150216869    4   -1  \
# 0  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
# 1  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
# 2  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
# 3  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
# 4  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
#
#      956    948  ...  \
# 0  956.0  855.0  ...
# 1  956.0  855.0  ...
# 2  956.0  948.0  ...
# 3  921.0  855.0  ...
# 4  921.0  855.0  ...
#
#    http://www.harpers.co.uk/news/ej-gallo-to-psychoanalyse-tweets-of-apothic-red-drinkers/513976.article  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    410641873  20150219164500  new-magazine.co.uk  \
# 0        NaN             NaN                 NaN
# 1        NaN             NaN                 NaN
# 2        NaN             NaN                 NaN
# 3        NaN             NaN                 NaN
# 4        NaN             NaN                 NaN
#
#   http://www.new-magazine.co.uk/latestnews/view/67271/John-Galliano-files-appeal-against-unfair-dismissal-ruling/  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    646 632  60 695 -3.17460317460318
# 0  NaN NaN NaN NaN               NaN
# 1  NaN NaN NaN NaN               NaN
# 2  NaN NaN NaN NaN               NaN
# 3  NaN NaN NaN NaN               NaN
# 4  NaN NaN NaN NaN               NaN
#
# [5 rows x 147 columns]
#
# Data telah disimpan sebagai 'gdelt_combined_Data.csv'

# %% [markdown]
# # Preprocessing

# %%
# Menampilkan nama kolom
print(all_data.columns)
# Out:
# Index(['410656065', '20150219174500', '20150219183000', '1', 'wickedlocal.com',
#        'http://boxborough.wickedlocal.com/article/20150219/NEWS/150216869',
#        '4', '-1', '956', '948',
#        ...
#        'http://www.harpers.co.uk/news/ej-gallo-to-psychoanalyse-tweets-of-apothic-red-drinkers/513976.article',
#        '410641873', '20150219164500', 'new-magazine.co.uk',
#        'http://www.new-magazine.co.uk/latestnews/view/67271/John-Galliano-files-appeal-against-unfair-dismissal-ruling/',
#        '646', '632', '60', '695', '-3.17460317460318'],
#       dtype='object', length=147)

# %%
# Menampilkan statistik deskriptif untuk beberapa kolom
print(all_data.describe())
# Out:
#           410656065  20150219174500  20150219183000             1  \
# count  1.070700e+04    1.070700e+04    3.455000e+04  53044.000000
# mean   4.105654e+08    2.015022e+13    2.015022e+13      0.910169
# std    3.452507e+05    4.423600e+06    3.594123e+06      0.294581
# min    4.039132e+08    2.015012e+13    2.015012e+13      0.000000
# 25%    4.105076e+08    2.015022e+13    2.015022e+13      1.000000
# 50%    4.106469e+08    2.015022e+13    2.015022e+13      1.000000
# 75%    4.106654e+08    2.015022e+13    2.015022e+13      1.000000
# max    4.106678e+08    2.015022e+13    2.015022e+13      2.000000
#
#                   4            -1           956           948           1.1  \
# count  33204.000000  20488.000000  10707.000000  10707.000000  53044.000000
# mean       5.624503   1854.295295   1302.220230   1890.000560      3.205716
# std       10.241081   3464.516792   2610.397058   2838.063885      5.290956
# min        0.000000     -1.000000     -1.000000     -1.000000      0.000000
# 25%        1.000000    231.000000     -1.000000    409.000000      1.000000
# 50%        4.000000    856.000000    418.000000   1104.000000      1.000000
# 75%        6.000000   2329.250000   1687.000000   2445.500000      4.000000
# max      175.000000  49867.000000  41584.000000  41545.000000    111.000000
#
#                  50  ...      51.5198    -0.076175  20150219190000  \
# count  30547.000000  ...  2876.000000  2876.000000    1.271500e+04
# mean      48.511801  ...    34.569362   -12.261405    2.015022e+13
# std       31.707526  ...    16.746587    72.989734    7.000275e+00
# min       10.000000  ...   -41.300000  -176.658000    2.015022e+13
# 25%       20.000000  ...    30.351050   -80.112350    2.015022e+13
# 50%       40.000000  ...    36.538300     6.000000    2.015022e+13
# 75%       80.000000  ...    43.410800    35.509700    2.015022e+13
# max      100.000000  ...    69.250600   175.000000    2.015022e+13
#
#           410641873  20150219164500           646           632           60  \
# count  9.781000e+03    9.781000e+03   9781.000000   9781.000000  9781.000000
# mean   4.105702e+08    2.015022e+13   1566.809017   2236.024844    48.227175
# std    3.955643e+05    5.322496e+06   3859.691086   4293.023134    31.818535
# min    4.039134e+08    2.015012e+13     -1.000000     -1.000000    10.000000
# 25%    4.105142e+08    2.015022e+13     -1.000000    416.000000    20.000000
# 50%    4.106516e+08    2.015022e+13    444.000000   1018.000000    40.000000
# 75%    4.106808e+08    2.015022e+13   1701.000000   2590.000000    80.000000
# max    4.106830e+08    2.015022e+13  49867.000000  49937.000000   100.000000
#
#                 695  -3.17460317460318
# count   9781.000000        9781.000000
# mean    4415.037317          -2.241680
# std     6752.466134           4.046969
# min      338.000000         -20.143885
# 25%     1637.000000          -4.403048
# 50%     2865.000000          -2.040816
# 75%     4818.000000           0.574713
# max    50730.000000          15.284553
#
# [8 rows x 63 columns]

# %%
# Menampilkan jumlah nilai kosong (NaN) per kolom
print(all_data.isnull().sum())
# Out:
# 410656065            55816
# 20150219174500       55816
# 20150219183000       31973
# 1                    13479
# wickedlocal.com      55816
#                      ...
# 646                  56742
# 632                  56742
# 60                   56742
# 695                  56742
# -3.17460317460318    56742
# Length: 147, dtype: int64

# %%
# Menghitung jumlah nilai yang bukan missing (non-NaN) di setiap kolom
non_missing_counts = all_data.count()

# Menampilkan jumlah nilai yang bukan missing untuk setiap kolom
print(non_missing_counts)
# Out:
# 410656065            10707
# 20150219174500       10707
# 20150219183000       34550
# 1                    53044
# wickedlocal.com      10707
#                      ...
# 646                   9781
# 632                   9781
# 60                    9781
# 695                   9781
# -3.17460317460318     9781
# Length: 147, dtype: int64

# %%
# Menampilkan kolom yang memiliki jumlah nilai non-missing lebih tinggi dari ambang batas tertentu
threshold = 50000  # Misalnya, hanya menampilkan kolom dengan lebih dari 50.000 nilai non-missing
filtered_columns = non_missing_counts[non_missing_counts > threshold]

# Menampilkan kolom-kolom yang memenuhi kriteria
print(filtered_columns)
# Out:
# 1      53044
# 1.1    53044
# dtype: int64

# %%
import numpy as np

# Menentukan rentang angka acak (misalnya antara 0 dan 100)
random_values = np.random.randint(0, 101, size=all_data.shape)

# Mengganti nilai yang hilang (NaN) dengan angka acak
all_data_filled = all_data.copy()  # Membuat salinan DataFrame untuk diubah
all_data_filled[:] = all_data_filled.fillna(pd.DataFrame(random_values, columns=all_data.columns))

# Menampilkan data setelah pengisian missing values dengan angka random
print(all_data_filled.head())

# Menyimpan data yang telah diperbarui
all_data_filled.to_csv('gdelt_combined_data_filled.csv', index=False)
print("\nData telah disimpan sebagai 'gdelt_combined_data_filled.csv'")
# Out:
#      410656065  20150219174500  20150219183000    1  wickedlocal.com  \
# 0  410656066.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
# 1  410656067.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
# 2  410656068.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
# 3  410656069.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
# 4  410656070.0    2.015022e+13    2.015022e+13  1.0  wickedlocal.com
#
#   http://boxborough.wickedlocal.com/article/20150219/NEWS/150216869    4   -1  \
# 0  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
# 1  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
# 2  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
# 3  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
# 4  http://boxborough.wickedlocal.com/article/2015...                 4.0 -1.0
#
#      956    948  ...  \
# 0  956.0  855.0  ...
# 1  956.0  855.0  ...
# 2  956.0  948.0  ...
# 3  921.0  855.0  ...
# 4  921.0  855.0  ...
#
#    http://www.harpers.co.uk/news/ej-gallo-to-psychoanalyse-tweets-of-apothic-red-drinkers/513976.article  \
# 0                                                 92
# 1                                                 35
# 2                                                 93
# 3                                                 86
# 4                                                 82
#
#    410641873  20150219164500  new-magazine.co.uk  \
# 0       75.0            36.0                  23
# 1       70.0            44.0                  32
# 2       90.0            66.0                  97
# 3       65.0            53.0                  81
# 4        8.0            55.0                   3
#
#   http://www.new-magazine.co.uk/latestnews/view/67271/John-Galliano-files-appeal-against-unfair-dismissal-ruling/  \
# 0                                                 52
# 1                                                 63
# 2                                                 59
# 3                                                 33
# 4                                                  2
#
#     646   632    60   695 -3.17460317460318
# 0  95.0  24.0  88.0  61.0              52.0
# 1  87.0   6.0  54.0  51.0              23.0
# 2  13.0  14.0  28.0  30.0              86.0
# 3   4.0   1.0  41.0  98.0              49.0
# 4  52.0  69.0  51.0  97.0              89.0
#
# [5 rows x 147 columns]
#
# Data telah disimpan sebagai 'gdelt_combined_data_filled.csv'

# %%
# Memeriksa apakah masih ada nilai NaN setelah pengisian
print(all_data_filled.isna().sum())
# Out:
# 410656065            0
# 20150219174500       0
# 20150219183000       0
# 1                    0
# wickedlocal.com      0
#                     ..
# 646                  0
# 632                  0
# 60                   0
# 695                  0
# -3.17460317460318    0
# Length: 147, dtype: int64

# %% [markdown]
# # Duplikasi data

# %%
# Menampilkan data yang duplikat
duplicate_data = all_data_filled[all_data_filled.duplicated()]

# Menampilkan beberapa baris yang duplikat
print(duplicate_data.head())
# Out:
# Empty DataFrame
# Columns: [410656065, 20150219174500, 20150219183000, 1, wickedlocal.com, http://boxborough.wickedlocal.com/article/20150219/NEWS/150216869, 4, -1, 956, 948, 1.1, 50, 5367, 2.89389067524115, Unnamed: 14, Unnamed: 15, 20150219183000-0, 2, BBC Monitoring, Etefaq-e Eslam, Herat/BBC Monitoring/(c) BBC, Unnamed: 5, Unnamed: 6, GENERAL_GOVERNMENT;TAX_RELIGION;TAX_RELIGION_ISLAMIC;LEADER;TAX_FNCACT;TAX_FNCACT_PRESIDENT;TAX_ETHNICITY;TAX_ETHNICITY_INDIAN;TAX_FNCACT_MINISTER;TAX_FNCACT_PRIME_MINISTER;TAX_FNCACT_LEADERS;TAX_FNCACT_AUTHORITIES;TAX_WORLDLANGUAGES;TAX_WORLDLANGUAGES_AFGHAN;TAX_AIDGROUPS;, TAX_ETHNICITY,292;TAX_ETHNICITY,608;GENERAL_GOVERNMENT,14;GENERAL_GOVERNMENT,1154;TAX_RELIGION,25;TAX_RELIGION,228;TAX_FNCACT,410;TAX_FNCACT,307;LEADER,213;LEADER,468;LEADER,543;LEADER,1047;TAX_FNCACT,213;TAX_FNCACT,468;TAX_FNCACT,543;TAX_FNCACT,1047;TAX_WORLDLANGUAGES,923;TAX_WORLDLANGUAGES,1143;TAX_AIDGROUPS,1486;TAX_FNCACT,620;TAX_FNCACT,307;, 1#Afghanistan#IN#AF#33#65#AF;1#India#IN#IN#20#77#IN, 1#Republic Of India#IN#IN##20#77#IN#506;1#India#IN#IN##20#77#IN#506;1#India#IN#IN##20#77#IN#580;1#India#IN#IN##20#77#IN#764;1#India#IN#IN##20#77#IN#939;1#India#IN#IN##20#77#IN#1068;1#Afghanistan#IN#AF##33#65#AF#49;1#Afghanistan#IN#AF##33#65#AF#252;1#Afghanistan#IN#AF##33#65#AF#558;1#Afghanistan#IN#AF##33#65#AF#844;1#Afghanistan#IN#AF##33#65#AF#1020;1#Afghan#IN#AF##33#65#AF#923;1#Afghan#IN#AF##33#65#AF#1143;1#Islamic Republic Of Afghanistan#IN#AF##33#65#AF#49;1#Islamic Republic Of Afghanistan#IN#AF##33#65#AF#252, ashraf ghani, Ashraf Ghani,267;Ashraf Ghani,481, Unnamed: 13, 1.98412698412698,3.96825396825397,1.98412698412698,5.95238095238095,16.6666666666667,0,230, Unnamed: 16, wc:230,c12.1:10,c12.10:21,c12.12:5,c12.13:5,c12.14:12,c12.3:2,c12.4:4,c12.5:5,c12.7:7,c12.8:9,c12.9:17,c14.1:11,c14.10:5,c14.11:15,c14.2:11,c14.3:10,c14.4:2,c14.5:19,c14.6:2,c14.7:1,c15.110:2,c15.154:1,c15.223:1,c15.260:1,c15.34:1,c15.43:1,c15.50:1,c15.81:1,c15.85:1,c15.97:1,c16.1:3,c16.100:7,c16.101:3,c16.105:2,c16.106:10,c16.109:10,c16.110:32,c16.111:1,c16.113:2,c16.114:13,c16.115:3,c16.116:3,c16.117:2,c16.118:13,c16.12:15,c16.120:7,c16.121:24,c16.124:1,c16.125:5,c16.126:8,c16.127:12,c16.128:1,c16.129:18,c16.13:1,c16.130:4,c16.131:8,c16.134:18,c16.138:4,c16.139:8,c16.14:1,c16.140:3,c16.145:19,c16.146:12,c16.152:1,c16.153:6,c16.155:3,c16.157:4,c16.159:22,c16.16:4,c16.161:22,c16.162:8,c16.163:10,c16.164:7,c16.165:1,c16.168:1,c16.17:2,c16.18:1,c16.19:2,c16.2:16,c16.21:2,c16.22:5,c16.26:21,c16.27:1,c16.3:3,c16.31:15,c16.32:1,c16.33:14,c16.34:1,c16.35:12,c16.36:1,c16.37:18,c16.38:3,c16.39:1,c16.4:15,c16.41:9,c16.43:4,c16.45:9,c16.46:3,c16.47:33,c16.48:1,c16.49:2,c16.5:1,c16.51:1,c16.52:16,c16.53:2,c16.54:1,c16.55:1,c16.56:9,c16.57:110,c16.58:18,c16.6:16,c16.61:1,c16.62:8,c16.63:1,c16.64:1,c16.65:5,c16.66:5,c16.68:12,c16.69:8,c16.7:8,c16.70:8,c16.71:2,c16.72:2,c16.74:1,c16.75:8,c16.78:4,c16.80:1,c16.82:1,c16.83:1,c16.84:7,c16.85:2,c16.86:1,c16.87:24,c16.88:16,c16.89:4,c16.9:1,c16.90:10,c16.91:6,c16.92:7,c16.93:2,c16.94:15,c16.95:13,c16.96:4,c16.98:17,c17.1:38,c17.10:26,c17.11:34,c17.12:6,c17.13:1,c17.14:2,c17.15:14,c17.16:9,c17.18:2,c17.19:11,c17.2:4,c17.20:2,c17.22:5,c17.23:1,c17.24:21,c17.25:4,c17.26:2,c17.27:19,c17.28:1,c17.29:9,c17.3:2,c17.30:4,c17.31:12,c17.32:7,c17.33:13,c17.34:5,c17.35:4,c17.36:10,c17.37:6,c17.38:1,c17.39:7,c17.4:33,c17.40:6,c17.41:8,c17.42:15,c17.43:13,c17.5:49,c17.7:26,c17.8:21,c17.9:4,c18.139:5,c18.179:2,c18.180:2,c18.193:8,c18.301:1,c18.342:3,c18.35:7,c2.1:9,c2.100:3,c2.101:5,c2.102:4,c2.104:26,c2.106:12,c2.107:4,c2.108:1,c2.109:2,c2.11:7,c2.110:7,c2.112:2,c2.113:2,c2.114:9,c2.115:2,c2.116:7,c2.117:1,c2.119:70,c2.12:9,c2.120:2,c2.121:11,c2.122:6,c2.125:8,c2.126:10,c2.127:14,c2.128:14,c2.129:31,c2.130:3,c2.131:1,c2.132:7,c2.133:4,c2.135:1,c2.136:7,c2.138:2,c2.139:3,c2.14:19,c2.140:1,c2.141:6,c2.143:30,c2.144:7,c2.145:4,c2.146:3,c2.147:42,c2.148:20,c2.15:17,c2.150:1,c2.151:1,c2.152:1,c2.153:3,c2.154:11,c2.155:27,c2.156:14,c2.157:24,c2.158:14,c2.159:1,c ...
# Index: []
#
# [0 rows x 147 columns]

# %%
# Menghapus duplikat berdasarkan semua kolom
all_data_cleaned = all_data_filled.drop_duplicates()

# Menampilkan jumlah data setelah dihapus duplikat
print(f"Jumlah baris setelah menghapus duplikat: {all_data_cleaned.shape[0]}")
# Out:
# Jumlah baris setelah menghapus duplikat: 66523

# %%
# Memeriksa jumlah duplikat setelah penghapusan
duplicate_rows_after = all_data_cleaned.duplicated().sum()

# Menampilkan hasilnya
print(f"Jumlah duplikat setelah penghapusan: {duplicate_rows_after}")
# Out:
# Jumlah duplikat setelah penghapusan: 0

# %%
# Menyimpan data yang sudah dibersihkan
all_data_cleaned.to_csv('gdelt_cleaned_data.csv', index=False)

# Memberikan informasi bahwa data telah disimpan
print("Data yang telah dibersihkan telah disimpan sebagai 'gdelt_cleaned_data.csv'")
# Out:
# Data yang telah dibersihkan telah disimpan sebagai 'gdelt_cleaned_data.csv'

# %% [markdown]
# # Filter negara indonesia

# %%
# Memeriksa apakah ada kolom yang berkaitan dengan negara
country_columns = [col for col in all_data_cleaned.columns if 'country' in str(col).lower() or 'indonesia' in str(col).lower()]

# Menampilkan hasilnya
if len(country_columns) > 0:
    print(f"Kolom yang berkaitan dengan negara ditemukan: {country_columns}")
else:
    print("Tidak ditemukan kolom yang berkaitan dengan negara.")
# Out:
# Tidak ditemukan kolom yang berkaitan dengan negara.

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
import requests
from bs4 import BeautifulSoup

# URL artikel yang ingin diambil
url = "https://blog.gdeltproject.org/gdelt-2-0-our-global-world-in-realtime/"

# Mengirim permintaan GET untuk mengambil halaman web
response = requests.get(url)

# Memeriksa jika permintaan berhasil
if response.status_code == 200:
    # Parsing konten HTML
    soup = BeautifulSoup(response.text, 'html.parser')

    # Mengambil semua teks dalam artikel (bisa disesuaikan dengan elemen HTML yang sesuai)
    # Misalnya artikel biasanya ada di dalam tag <article> atau <div> dengan kelas tertentu
    article_content = soup.get_text()  # Untuk mengambil seluruh teks artikel

    # Menampilkan potongan teks dari artikel
    print(article_content[:1000])  # Menampilkan 1000 karakter pertama

    # Memeriksa apakah ada kata kunci Indonesia dalam artikel
    keywords = ['indonesia', 'jakarta', 'bali', 'surabaya', 'medan', 'bandung']
    found_keywords = [keyword for keyword in keywords if keyword.lower() in article_content.lower()]

    if found_keywords:
        print(f"Ditemukan kata kunci terkait Indonesia: {', '.join(found_keywords)}")
    else:
        print("Tidak ditemukan kata kunci terkait Indonesia.")
else:
    print("Gagal mengunduh halaman.")
# Out:
# GDELT 2.0: Our Global World in Realtime – The GDELT Project
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The GDELT Project
#
#
#
#
#
#
#
#
#
#
#
# The GDELT Project Blog
# Website
#
#
#
#
#
#
#
# Search for:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# GDELT 2.0: Our Global World in Realtime
#
#  February 19, 2015
#
#
#
# We are enormously excited to announce today the unveiling of the future of GDELT.  GDELT 2.0 debuts what we believe is one of the largest and most ambitious platforms ever created for monitoring our global world. From realtime translation of the world’s news in 65 languages, to measurement of more than 2,300 emotions and themes from every article, to a massive inventory of the media of the non-Western world, GDELT 2.0 is poised to redefine how we understand and interact with our global world, transcending language barriers and reaching deeply into the reactions and emotional resonance of world events. In essence, within 15 minutes of GDELT monitoring a news report breaking anywhere the world, it has translated it, process
# Ditemukan kata kunci terkait Indonesia: indonesia

# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# Path file CSV yang telah diunggah
file_path = '/content/results-20241207040137.csv'

# %%
# Membaca file CSV dan melewati baris yang bermasalah
df = pd.read_csv(file_path, on_bad_lines='skip')

# %%
import pandas as pd

file_path = '/content/results-20241207040137.csv'

# Membaca file CSV dan melewati baris yang bermasalah
df = pd.read_csv(file_path, on_bad_lines='skip')

# Menampilkan beberapa baris pertama untuk memastikan data berhasil dibaca
print(df.head())
# Out:
#                            Location  LocationResultCount  Latitude  Longitude  \
# 0                         Indonesia                 6059   -5.0000    120.000
# 1  Jakarta, Jakarta Raya, Indonesia                  904   -6.1744    106.829
# 2  Jakarta, Jakarta Raya, Indonesia                  904   -6.1744    106.829
# 3  Jakarta, Jakarta Raya, Indonesia                  904   -6.1744    106.829
# 4  Jakarta, Jakarta Raya, Indonesia                  904   -6.1744    106.829
#
#                                                  URL  \
# 0  https://www.liputan6.com/showbiz/read/5822753/...
# 1           https://www.chinaz.com/tags/915799.shtml
# 2  https://www.cnnindonesia.com/olahraga/20241206...
# 3  https://www.merdeka.com/sepakbola/bangga-momen...
# 4  https://www.liputan6.com/tekno/read/5822357/to...
#
#                                             ImageURL  \
# 0  https://cdn0-production-images-kly.akamaized.n...
# 1                                                NaN
# 2  https://akcdn.detik.net.id/visual/2024/03/26/v...
# 3  https://cdns.klimg.com/mav-prod-resized/0x0/or...
# 4  https://cdn1-production-images-kly.akamaized.n...
#
#                                                Title
# 0  Onad Lawan Bobby Saputra di Superstar Knock Ou...
# 1                           印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼
# 2  Tiket Vietnam vs Indonesia di Piala AFF 2024 S...
# 3  Bangga ! Momen Skuad Timnas Indonesia Putri Ti...
# 4  Top 3 Tekno : Ini Dampak iPhone 16 Masih Ilega...

# %%
# Menampilkan informasi umum tentang DataFrame
print(df.info())

# Menampilkan statistik deskriptif dari data numerik
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Location             997 non-null    object
#  1   LocationResultCount  997 non-null    int64
#  2   Latitude             997 non-null    float64
#  3   Longitude            997 non-null    float64
#  4   URL                  997 non-null    object
#  5   ImageURL             786 non-null    object
#  6   Title                996 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 54.6+ KB
# None
#        LocationResultCount    Latitude   Longitude
# count           997.000000  997.000000  997.000000
# mean             27.448345   11.483588   68.473363
# std             204.961409   22.021714   65.084174
# min               1.000000  -42.000000 -158.113000
# 25%               2.000000   -6.933000   29.000000
# 50%               4.000000    3.166700  103.800000
# 75%              12.000000   30.827700  112.463000
# max            6059.000000   64.000000  174.000000

# %%
# Memeriksa nilai yang hilang (missing values) di setiap kolom
missing_values = df.isnull().sum()

# Menampilkan hasilnya
print(missing_values)
# Out:
# Location                 0
# LocationResultCount      0
# Latitude                 0
# Longitude                0
# URL                      0
# ImageURL               211
# Title                    1
# dtype: int64

# %%
# mengisi nilai hilang pada kolom 'ImageURL' dengan string 'No Image'
df['ImageURL'] = df['ImageURL'].fillna('No Image')

# %%
# mengisi nilai hilang pada kolom 'Title' dengan string placeholder
df['Title'] = df['Title'].fillna('No Title')

# %%
# Menampilkan data yang terkait dengan lokasi tertentu
filtered_data = df[df['Location'].str.contains('Jakarta')]
filtered_data.head()
# Out:
#                                    Location  LocationResultCount  Latitude  \
# 1          Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 2          Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 3          Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 4          Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 682  Kelapa Gading, Jakarta Raya, Indonesia                    2   -6.1650
#
#      Longitude                                                URL  \
# 1      106.829           https://www.chinaz.com/tags/915799.shtml
# 2      106.829  https://www.cnnindonesia.com/olahraga/20241206...
# 3      106.829  https://www.merdeka.com/sepakbola/bangga-momen...
# 4      106.829  https://www.liputan6.com/tekno/read/5822357/to...
# 682    106.906  https://www.nowjakarta.co.id/new-general-manag...
#
#                                               ImageURL  \
# 1                                             No Image
# 2    https://akcdn.detik.net.id/visual/2024/03/26/v...
# 3    https://cdns.klimg.com/mav-prod-resized/0x0/or...
# 4    https://cdn1-production-images-kly.akamaized.n...
# 682  https://www.nowjakarta.co.id/wp-content/upload...
#
#                                                  Title
# 1                             印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼
# 2    Tiket Vietnam vs Indonesia di Piala AFF 2024 S...
# 3    Bangga ! Momen Skuad Timnas Indonesia Putri Ti...
# 4    Top 3 Tekno : Ini Dampak iPhone 16 Masih Ilega...
# 682  New General Managers Take Helm at Indonesia Le...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot Latitude dan Longitude
plt.figure(figsize=(10, 6))  # Menentukan ukuran plot
plt.scatter(df['Longitude'], df['Latitude'], alpha=0.5, color='b')  # Membuat scatter plot
plt.title('Distribusi Latitude dan Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)  # Menambahkan grid agar lebih mudah dilihat
plt.show()

# %%
# Analisis distribusi Latitude dan Longitude
longitude_range = df['Longitude'].min(), df['Longitude'].max()
latitude_range = df['Latitude'].min(), df['Latitude'].max()

# Menyusun analisis berdasarkan range koordinat
print(f"Rentang Longitude: {longitude_range[0]} hingga {longitude_range[1]}")
print(f"Rentang Latitude: {latitude_range[0]} hingga {latitude_range[1]}")
# Out:
# Rentang Longitude: -158.113 hingga 174.0
# Rentang Latitude: -42.0 hingga 64.0

# %%
# Menghitung konsentrasi data
data_density = df.groupby(['Latitude', 'Longitude']).size().reset_index(name='Density')
high_density_locations = data_density[data_density['Density'] > 1]  # Lokasi dengan lebih dari satu data

print(f"\nJumlah lokasi dengan konsentrasi data lebih dari satu: {len(high_density_locations)}")
# Out:
# Jumlah lokasi dengan konsentrasi data lebih dari satu: 233

# %%
# Filter lokasi Jakarta dan Bali
jakarta_bali_df = df[df['Location'].str.contains('Jakarta|Bali', case=False, na=False)]

# Plot Latitude dan Longitude untuk Jakarta dan Bali
plt.figure(figsize=(10, 6))  # Menentukan ukuran plot
plt.scatter(jakarta_bali_df['Longitude'], jakarta_bali_df['Latitude'], alpha=0.5, color='r')  # Membuat scatter plot dengan warna merah
plt.title('Distribusi Latitude dan Longitude - Jakarta dan Bali')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)  # Menambahkan grid agar lebih mudah dilihat
plt.show()

# Menampilkan jumlah data yang terfilter untuk Jakarta dan Bali
print(f"Jumlah data untuk Jakarta dan Bali: {jakarta_bali_df.shape[0]}")
# Out:
# Jumlah data untuk Jakarta dan Bali: 34

# %%
# Filter lokasi Jakarta dan Bali
jakarta_bali_df = df[df['Location'].str.contains('Jakarta|Bali', case=False, na=False)]

# Menampilkan 5 baris pertama dari data terfilter
print("5 Baris Pertama Data Jakarta dan Bali:")
print(jakarta_bali_df.head())
# Out:
# 5 Baris Pertama Data Jakarta dan Bali:
#                             Location  LocationResultCount  Latitude  \
# 1   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 2   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 3   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 4   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 17       Bali, Jawa Timur, Indonesia                  168   -7.1046
#
#     Longitude                                                URL  \
# 1     106.829           https://www.chinaz.com/tags/915799.shtml
# 2     106.829  https://www.cnnindonesia.com/olahraga/20241206...
# 3     106.829  https://www.merdeka.com/sepakbola/bangga-momen...
# 4     106.829  https://www.liputan6.com/tekno/read/5822357/to...
# 17    112.337  https://hijau.bisnis.com/read/20241206/651/182...
#
#                                              ImageURL  \
# 1                                            No Image
# 2   https://akcdn.detik.net.id/visual/2024/03/26/v...
# 3   https://cdns.klimg.com/mav-prod-resized/0x0/or...
# 4   https://cdn1-production-images-kly.akamaized.n...
# 17  https://images.bisnis.com/posts/2024/12/06/182...
#
#                                                 Title
# 1                            印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼
# 2   Tiket Vietnam vs Indonesia di Piala AFF 2024 S...
# 3   Bangga ! Momen Skuad Timnas Indonesia Putri Ti...
# 4   Top 3 Tekno : Ini Dampak iPhone 16 Masih Ilega...
# 17  Di Hadapan Jepang , Pemerintah Indonesia Sebut...

# %%
# Statistik deskriptif untuk kolom numerik
print("\nStatistik Deskriptif:")
print(jakarta_bali_df[['Latitude', 'Longitude', 'LocationResultCount']].describe())
# Out:
# Statistik Deskriptif:
#         Latitude   Longitude  LocationResultCount
# count  34.000000   34.000000            34.000000
# mean   -2.662124  110.298097           131.088235
# std    12.435312   15.835809           291.333649
# min    -8.833300   24.783300             1.000000
# 25%    -8.509800  106.847750             2.000000
# 50%    -7.104600  114.937000             4.000000
# 75%    -6.174400  115.231000            37.000000
# max    35.416700  122.148000           904.000000

# %%
import matplotlib.pyplot as plt

# Membuat histogram untuk distribusi LocationResultCount
plt.figure(figsize=(10, 6))
n, bins, patches = plt.hist(jakarta_bali_df['LocationResultCount'], bins=10, color='b', edgecolor='black', alpha=0.7)

# Menambahkan angka frekuensi di atas setiap batang histogram
for i in range(len(patches)):
    plt.text(patches[i].get_x() + patches[i].get_width() / 2, n[i] + 0.2, str(int(n[i])),
             ha='center', va='bottom', fontsize=10, color='black')

# Menambahkan judul dan label sumbu
plt.title('Distribusi LocationResultCount untuk Jakarta dan Bali')
plt.xlabel('LocationResultCount')
plt.ylabel('Frekuensi')

# Menampilkan grid dan plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Filter Events Code Sesuai Minat

# %%
# Memeriksa kolom-kolom yang ada dalam DataFrame
print(jakarta_bali_df.columns)
# Out:
# Index(['Location', 'LocationResultCount', 'Latitude', 'Longitude', 'URL',
#        'ImageURL', 'Title'],
#       dtype='object')

# %%
# Memeriksa beberapa baris pertama dari data yang telah difilter
print(jakarta_bali_df.head())
# Out:
#                             Location  LocationResultCount  Latitude  \
# 1   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 2   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 3   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 4   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 17       Bali, Jawa Timur, Indonesia                  168   -7.1046
#
#     Longitude                                                URL  \
# 1     106.829           https://www.chinaz.com/tags/915799.shtml
# 2     106.829  https://www.cnnindonesia.com/olahraga/20241206...
# 3     106.829  https://www.merdeka.com/sepakbola/bangga-momen...
# 4     106.829  https://www.liputan6.com/tekno/read/5822357/to...
# 17    112.337  https://hijau.bisnis.com/read/20241206/651/182...
#
#                                              ImageURL  \
# 1                                            No Image
# 2   https://akcdn.detik.net.id/visual/2024/03/26/v...
# 3   https://cdns.klimg.com/mav-prod-resized/0x0/or...
# 4   https://cdn1-production-images-kly.akamaized.n...
# 17  https://images.bisnis.com/posts/2024/12/06/182...
#
#                                                 Title
# 1                            印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼
# 2   Tiket Vietnam vs Indonesia di Piala AFF 2024 S...
# 3   Bangga ! Momen Skuad Timnas Indonesia Putri Ti...
# 4   Top 3 Tekno : Ini Dampak iPhone 16 Masih Ilega...
# 17  Di Hadapan Jepang , Pemerintah Indonesia Sebut...

# %%
# Filter untuk data dengan lokasi yang mengandung 'Jakarta' dan 'Bali'
jakarta_bali_events = jakarta_bali_df[jakarta_bali_df['Location'].str.contains('Jakarta|Bali', case=False, na=False)]

# Menampilkan beberapa baris pertama setelah filter
print(jakarta_bali_events.head())

# Menampilkan jumlah data setelah filter
print(f"Jumlah data untuk Jakarta dan Bali: {jakarta_bali_events.shape[0]}")
# Out:
#                             Location  LocationResultCount  Latitude  \
# 1   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 2   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 3   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 4   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 17       Bali, Jawa Timur, Indonesia                  168   -7.1046
#
#     Longitude                                                URL  \
# 1     106.829           https://www.chinaz.com/tags/915799.shtml
# 2     106.829  https://www.cnnindonesia.com/olahraga/20241206...
# 3     106.829  https://www.merdeka.com/sepakbola/bangga-momen...
# 4     106.829  https://www.liputan6.com/tekno/read/5822357/to...
# 17    112.337  https://hijau.bisnis.com/read/20241206/651/182...
#
#                                              ImageURL  \
# 1                                            No Image
# 2   https://akcdn.detik.net.id/visual/2024/03/26/v...
# 3   https://cdns.klimg.com/mav-prod-resized/0x0/or...
# 4   https://cdn1-production-images-kly.akamaized.n...
# 17  https://images.bisnis.com/posts/2024/12/06/182...
#
#                                                 Title
# 1                            印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼
# 2   Tiket Vietnam vs Indonesia di Piala AFF 2024 S...
# 3   Bangga ! Momen Skuad Timnas Indonesia Putri Ti...
# 4   Top 3 Tekno : Ini Dampak iPhone 16 Masih Ilega...
# 17  Di Hadapan Jepang , Pemerintah Indonesia Sebut...
# Jumlah data untuk Jakarta dan Bali: 34

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.8.30)

# %%
import folium

# Membuat peta dengan titik tengah di Indonesia
map_center = [ -6.2, 106.8 ]  # Titik tengah antara Jakarta dan Bali
mymap = folium.Map(location=map_center, zoom_start=6)

# Menambahkan marker untuk setiap event di Jakarta dan Bali
for idx, row in jakarta_bali_events.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Title'],  # Menampilkan judul event saat marker diklik
        icon=folium.Icon(color='blue', icon='info-sign')  # Icon untuk marker
    ).add_to(mymap)

# Menyimpan peta ke dalam file HTML
mymap.save('peta_jakarta_bali.html')

# Menampilkan peta
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_164fc47e715f99fe27dfe78de95d51a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_164fc47e715f99fe27dfe78de95d51a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_164fc47e715f99fe27dfe78de95d51a8 = L.map(
#                 &quot;map_164fc47e715f99fe27dfe78de95d51a8&quot;,
#                 {
#                     center: [-6.2, 106.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d61b0c46e5b16954cf01e2097d1fb15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7d61b0c46e5b16954cf01e2097d1fb15.addTo(map_164fc47e715f99fe27dfe78de95d51a8);
#
#
#             var marker_ffcd81f5b2d1f0e0e5f8a9bb5f94cef0 = L.marker(
#                 [-6.1744, 106.829],
#                 {}
#             ).addTo(map_164fc47e715f99fe27dfe78de95d51a8);
#
#
#             var icon_174422d7b467fa27b9042255b8accda5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ffcd81f5b2d1f0e0e5f8a9bb5f94cef0.setIcon(icon_174422d7b467fa27b9042255b8accda5);
#
#
#         var popup_0582c54a3485b2827b9bb5cbb785ab4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c46583d91aa76c9fc079f3105076026 = $(`&lt;div id=&quot;html_8c46583d91aa76c9fc079f3105076026&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼&lt;/div&gt;`)[0];
#                 popup_0582c54a3485b2827b9bb5cbb785ab4c.setContent(html_8c46583d91aa76c9fc079f3105076026);
#
#
#
#         marker_ffcd81f5b2d1f0e0e5f8a9bb5f94cef0.bindPopup(popup_0582c54a3485b2827b9bb5cbb785ab4c)
#         ;
#
#
#
#
#             var marker_3fb2b479bffd44cee3dfcc24a2c305f6 = L.marker(
#                 [-6.1744, 106.829],
#                 {}
#             ).addTo(map_164fc47e715f99fe27dfe78de95d51a8);
#
#
#             var icon_decb6797d3c19b20be68d47b7cca34fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3fb2b479bffd44cee3dfcc24a2c305f6.setIcon(icon_decb6797d3c19b20be68d47b7cca34fe);
#
#
#         var popup_1e388d5c1d77d33ccb5eeb9617427449 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_821491e6bdda7d5cc1db933d1e034724 = $(`&lt;div id=&quot;html_821491e6bdda7d5cc1db933d1e034724&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tiket Vietnam vs Indonesia di Piala AFF 2024 Sold Out&lt;/div&gt;`)[0];
#                 popup_1e388d5c1d77d33ccb5eeb9617427449.setContent(html_821491e6bdda7d5cc1db933d1e034724);
#
#
#
#         marker_3fb2b479bffd44cee3dfcc24a2c305f6.bindPopup(popup_1e388d5c1d77d33ccb5eeb9617427449)
#         ;
#
#
#
#
#             var marker_4a2765450eee1f35528633fc39210547 = L.marker(
#                 [-6.1744, 106.829],
#                 {}
#             ).addTo(map_164fc47e715f99fe27dfe78de95d51a8);
#
#
#             var icon_1b82e313c33bfd9e34f88fad5b0359be = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a2765450eee1f35528633fc39210547.setIcon(icon_1b82e313c33bfd9e34f88fad5b0359be);
#
#
#         var popup_395207d33650964a69b71a28d5f2af92 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97bb41f95b8e79dbc88ce097f89190f5 = $(`&lt;div id=&quot;html_97bb41f95b8e79dbc88ce097f89190f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bangga ! Momen Skuad Timnas Indonesia Putri Tiba di Jakarta , Bawa Trofi Juara Piala AFF Wanita 2024&lt;/div&gt;`)[0];
#                 popup_395207d33650964a69b71a28d5f2af92.setContent(html_97bb41f95b8e79dbc88ce097f89190f5);
#
#
#
#         marker_4a2765450eee1f35528633fc39210547.bindPopup(popup_395207d33650964a69b71a28d5f2af92)
#         ;
#
#
#
#
#             var marker_550c764719f4762b4b68267229bd893c = L.marker(
#                 [-6.1744, 106.829],
#                 {}
#             ).addTo(map_164fc47e715f99fe27dfe78de95d51a8);
#
#
#             var icon_667400c438bea8c9c9001ec5a404e033 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;:

# %%
from IPython.display import IFrame

# Menampilkan peta yang telah disimpan dalam file HTML
IFrame('peta_jakarta_bali.html', width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="peta_jakarta_bali.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Analisis Deskriptif Data yang ada

# %%
# Ringkasan statistik dari data numerik
descriptive_stats = jakarta_bali_events[['Latitude', 'Longitude', 'LocationResultCount']].describe()
print(descriptive_stats)
# Out:
#         Latitude   Longitude  LocationResultCount
# count  34.000000   34.000000            34.000000
# mean   -2.662124  110.298097           131.088235
# std    12.435312   15.835809           291.333649
# min    -8.833300   24.783300             1.000000
# 25%    -8.509800  106.847750             2.000000
# 50%    -7.104600  114.937000             4.000000
# 75%    -6.174400  115.231000            37.000000
# max    35.416700  122.148000           904.000000

# %%
import matplotlib.pyplot as plt

# Visualisasi distribusi LocationResultCount
plt.figure(figsize=(10, 6))
n, bins, patches = plt.hist(jakarta_bali_events['LocationResultCount'], bins=10, color='purple', edgecolor='black', alpha=0.7)

# Menambahkan jumlah di atas setiap bin
for i in range(len(patches)):
    plt.text(patches[i].get_x() + patches[i].get_width() / 2, n[i] + 0.2,  # Posisi teks di atas bin
             str(int(n[i])),  # Nilai frekuensi, diubah ke integer
             ha='center',      # Horizontal alignment
             va='bottom',      # Vertical alignment
             fontsize=12)

# Judul dan label
plt.title('Distribusi LocationResultCount untuk Jakarta dan Bali')
plt.xlabel('LocationResultCount')
plt.ylabel('Frekuensi')

# Menampilkan grid
plt.grid(True)

# Menampilkan plot
plt.show()

# %%
# Matriks korelasi untuk data numerik
correlation_matrix = jakarta_bali_events[['Latitude', 'Longitude', 'LocationResultCount']].corr()
print(correlation_matrix)
# Out:
#                      Latitude  Longitude  LocationResultCount
# Latitude             1.000000  -0.378446            -0.134042
# Longitude           -0.378446   1.000000            -0.068923
# LocationResultCount -0.134042  -0.068923             1.000000

# %%
import seaborn as sns

# Visualisasi heatmap korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Matriks Korelasi Jakarta dan Bali')
plt.show()

# %%
# Jumlah event berdasarkan Title
event_counts = jakarta_bali_events['Title'].value_counts()
print(event_counts.head(10))  # Menampilkan 10 event terpopuler
# Out:
# Title
# Mary Jane Akan Dipulangkan Ke Filipina Sebelum Natal 2024                                                                                                                        2
# Bali Rutin Dipakai WNA Buronan Masuk Indonesia , Ini Catatan NCB Interpol                                                                                                        2
# Solidaritas untuk Ahmadiyah                                                                                                                                                      2
# Rate Money Changer - Bali Hari ini . domino qiu qiu pro hdi . 76kbet top - apk go win slot                                                                                       2
# 印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼                                                                                                                                                         1
# Fresh pictures of Bali Nine members Matthew Norman and Si - Yi Chen inside jail stoke speculation their release could be imminent                                                1
# Pemandangan . gf777com apk . download apk mt777 apk download - qiu qiu pro versi lama                                                                                            1
# Motif Remaja Bunuh Ayah dan Nenek di Lebak Bulus Masih Ditelusuri Apsifor                                                                                                        1
# 5 singa . DOWNLOAD APK SS88BET Metadata Indeks Tingkatkan kemampuan bermain Mahjong Wins 3 . ACEPH Update Core Mahjong Wins 3 selalu penuh tantangan - qiu qiu pro versi lama    1
# World Bank vows record $100bn support for world poorest countries                                                                                                                1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Visualisasi jumlah event berdasarkan Title
plt.figure(figsize=(10, 6))
ax = event_counts.head(10).plot(kind='bar', color='orange', edgecolor='black', alpha=0.7)

# Menambahkan jumlah di atas setiap batang
for i in range(len(event_counts.head(10))):
    ax.text(i, event_counts.head(10).iloc[i] + 0.2,  # Posisi teks di atas batang
            str(event_counts.head(10).iloc[i]),         # Nilai jumlah
            ha='center',                               # Horizontal alignment
            va='bottom',                               # Vertical alignment
            fontsize=12)

# Judul dan label
plt.title('Jumlah Event Berdasarkan Title untuk Jakarta dan Bali')
plt.xlabel('Judul Event')
plt.ylabel('Jumlah Event')

# Menambahkan rotasi pada label x
plt.xticks(rotation=45, ha='right')

# Menampilkan grid
plt.grid(True)

# Menampilkan plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21360 (\N{CJK UNIFIED IDEOGRAPH-5370}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32463 (\N{CJK UNIFIED IDEOGRAPH-7ECF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27982 (\N{CJK UNIFIED IDEOGRAPH-6D4E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26032 (\N{CJK UNIFIED IDEOGRAPH-65B0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36164 (\N{CJK UNIFIED IDEOGRAPH-8D44}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35759 (\N{CJK UNIFIED IDEOGRAPH-8BAF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21160 (\N{CJK UNIFIED IDEOGRAPH-52A8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24577 (\N{CJK UNIFIED IDEOGRAPH-6001}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Menghitung jumlah event unik berdasarkan Title
unique_events = jakarta_bali_events['Title'].nunique()
print(f"Jumlah event unik: {unique_events}")
# Out:
# Jumlah event unik: 30

# %%
# Menampilkan jumlah Title per lokasi
title_per_location = jakarta_bali_events.groupby('Location')['Title'].value_counts()
print(title_per_location)
# Out:
# Location                                Title
# Bali, Hsin-Pei Shih, Taiwan             OPPO Find X8系列国内销量破百万 海外屡破纪录                                                                                                                                                     1
# Bali, Jawa Timur, Indonesia             Bali Rutin Dipakai WNA Buronan Masuk Indonesia , Ini Catatan NCB Interpol                                                                                                        1
#                                         Di Hadapan Jepang , Pemerintah Indonesia Sebut Berhasil Kurangi 128 Juta Ton Emisi Karbon pada 2023                                                                              1
#                                         Mary Jane Akan Dipulangkan Ke Filipina Sebelum Natal 2024                                                                                                                        1
#                                         Timnas Indonesia Dinilai Tak Serius Tampil di Piala AFF 2024 , Menpora Buka Suara                                                                                                1
# Bali, Perifereia Kritis, Greece         5 singa . DOWNLOAD APK SS88BET Metadata Indeks Tingkatkan kemampuan bermain Mahjong Wins 3 . ACEPH Update Core Mahjong Wins 3 selalu penuh tantangan - qiu qiu pro versi lama    1
# Bali, Zamboanga Del Norte, Philippines  Pulangkan Terpidana Mati Bali Nine dan Mary Jane , Indonesia akan Terus Perangi Narkoba                                                                                          1
# Bali, Zhejiang, China                   印尼逮捕一名因据称参与为网络赌博组织洗钱而被北京通缉的中国男子                                                                                                                                                  1
#                                         印尼逮捕一名因洗钱罪被北京通缉的中国男子                                                                                                                                                             1
# Cikini, Jakarta Raya, Indonesia         Solidaritas untuk Ahmadiyah                                                                                                                                                      1
# Cilandak, Jakarta Raya, Indonesia       Motif Remaja Bunuh Ayah dan Nenek di Lebak Bulus Masih Ditelusuri Apsifor                                                                                                        1
# Cililitan, Jakarta Raya, Indonesia      Kesiapan Minim , Warga Jakarta Masih Rentan terhadap Ancaman Gempa                                                                                                               1
# Denpasar, Bali, Indonesia               Bali Rutin Dipakai WNA Buronan Masuk Indonesia , Ini Catatan NCB Interpol                                                                                                        1
#                                         Komisi I DPR RI kunjungi Kodam Udayana perkuat Astacita Presiden RI                                                                                                              1
#                                         Seni Jadi Jembatan Persahabatan China - ASEAN                                                                                                                                    1
#                                         Wahyu Eka Putra Dilantik Jadi Kakanwil Kemenkum Bali , Menkum Supratman Berpesan                                                                                                 1
# Jakarta, Jakarta Raya, Indonesia        Bangga ! Momen Skuad Timnas Indonesia Putri Tiba di Jakarta , Bawa Trofi Juara Piala AFF Wanita 2024                                                                             1
#                                         Tiket Vietnam vs Indonesia di Piala AFF 2024 Sold Out                                                                                                                            1
#                                         Top 3 Tekno : Ini Dampak iPhone 16 Masih Ilegal di Indonesia                                                                                                                     1
#                                         印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼                                                                                                                                                         1
# Kelapa Gading, Jakarta Raya, Indonesia  New General Managers Take Helm at Indonesia Leading Hotels                                                                                                                       1
# Kerobokan, Bali, Indonesia              Convicted drug smuggler Schapelle Corby shares ' sad ' life update as she announces reluctant career change : ' Biggest regret '                                                 1
#                                         Fresh pictures of Bali Nine members Matthew Norman and Si - Yi Chen inside jail stoke speculation their release could be imminent                                                1
# Menteng, Jakarta Raya, Indonesia        Criollo , Resto Serba Cokelat di Jakarta yang Hadirkan Menu Gurih                                                                                                                1
#                                         Solidaritas untuk Ahmadiyah                                                                                                                                                      1
# Nusa Dua, Bali, Indonesia               Improving the airport passenger experience                                                                                                                                       1
#                                         World Bank vows record $100bn support for world poorest countries                                                                                                                1
# Peradi, Bali, Indonesia                 Mary Jane Akan Dipulangkan Ke Filipina Sebelum Natal 2024                                                                                                                        1
#                                         Perkuat organisasi sebagai state organ , Peradi gelar rakernas di Bali                                                                                                           1
# Purbalingga, Jawa Tengah, Indonesia     Cerita Petani Lada di Purbalingga Sukses Tembus Pasar Internasional                                                                                                              1
# Seminyak, Bali, Indonesia               Rate Money Changer - Bali Hari ini . domino qiu qiu pro hdi . 76kbet top - apk go win slot                                                                                       1
# Ubud, Bali, Indonesia                   Rate Money Changer - Bali Hari ini . domino qiu qiu pro hdi . 76kbet top - apk go win slot                                                                                       1
#                                         YAMPU TOURS LAUNCHES SPIRITUAL AND WELLNESS TOURS IN PERU , GUATEMALA , AND BALI , INDONESIA                                                                                     1
# Uluwatu, Bali, Indonesia                Pemandangan . gf777com apk . download apk mt777 apk download - qiu qiu pro versi lama                                                                                            1
# Name: count, dtype: int64

# %%
# Visualisasi pie chart berdasarkan Title di Jakarta dan Bali
location_counts = jakarta_bali_events['Location'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(location_counts, labels=location_counts.index, autopct='%1.1f%%', startangle=90, colors=['blue', 'red'])
plt.title('Distribusi Event Berdasarkan Lokasi (Jakarta vs Bali)')
plt.show()

# %% [markdown]
# # Filter provinsi lainnya

# %%
# Mengambil semua provinsi yang unik dari kolom 'Location'
unique_locations = jakarta_bali_df['Location'].unique()

# Menghapus Jakarta dan Bali dari daftar provinsi
other_locations = [location for location in unique_locations if 'Jakarta' not in location and 'Bali' not in location]

# Menampilkan daftar provinsi lainnya selain Jakarta dan Bali
print("Daftar provinsi selain Jakarta dan Bali:")
print(other_locations)
# Out:
# Daftar provinsi selain Jakarta dan Bali:
# ['Purbalingga, Jawa Tengah, Indonesia']

# %%
# Filter data untuk Jakarta, Bali, dan Purbalingga
locations_to_filter = ['Jakarta', 'Bali', 'Purbalingga']
filtered_df = df[df['Location'].str.contains('|'.join(locations_to_filter))]

# Menampilkan 5 data teratas dari hasil filter
filtered_df.head()
# Out:
#                             Location  LocationResultCount  Latitude  \
# 1   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 2   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 3   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 4   Jakarta, Jakarta Raya, Indonesia                  904   -6.1744
# 17       Bali, Jawa Timur, Indonesia                  168   -7.1046
#
#     Longitude                                                URL  \
# 1     106.829           https://www.chinaz.com/tags/915799.shtml
# 2     106.829  https://www.cnnindonesia.com/olahraga/20241206...
# 3     106.829  https://www.merdeka.com/sepakbola/bangga-momen...
# 4     106.829  https://www.liputan6.com/tekno/read/5822357/to...
# 17    112.337  https://hijau.bisnis.com/read/20241206/651/182...
#
#                                              ImageURL  \
# 1                                            No Image
# 2   https://akcdn.detik.net.id/visual/2024/03/26/v...
# 3   https://cdns.klimg.com/mav-prod-resized/0x0/or...
# 4   https://cdn1-production-images-kly.akamaized.n...
# 17  https://images.bisnis.com/posts/2024/12/06/182...
#
#                                                 Title
# 1                            印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼
# 2   Tiket Vietnam vs Indonesia di Piala AFF 2024 S...
# 3   Bangga ! Momen Skuad Timnas Indonesia Putri Ti...
# 4   Top 3 Tekno : Ini Dampak iPhone 16 Masih Ilega...
# 17  Di Hadapan Jepang , Pemerintah Indonesia Sebut...

# %%
# Melihat distribusi lokasi berdasarkan kolom 'Location'
location_counts = filtered_df['Location'].value_counts()

# Menampilkan distribusi lokasi
location_counts.plot(kind='bar', color='skyblue', alpha=0.7)
plt.title('Distribusi Lokasi Jakarta, Bali, dan Purbalingga')
plt.xlabel('Lokasi')
plt.ylabel('Jumlah Event')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Menampilkan angka distribusi
print(location_counts)
# Out:
# Location
# Jakarta, Jakarta Raya, Indonesia          4
# Denpasar, Bali, Indonesia                 4
# Bali, Jawa Timur, Indonesia               4
# Peradi, Bali, Indonesia                   2
# Bali, Zhejiang, China                     2
# Kerobokan, Bali, Indonesia                2
# Ubud, Bali, Indonesia                     2
# Menteng, Jakarta Raya, Indonesia          2
# Nusa Dua, Bali, Indonesia                 2
# Cikini, Jakarta Raya, Indonesia           1
# Uluwatu, Bali, Indonesia                  1
# Seminyak, Bali, Indonesia                 1
# Cilandak, Jakarta Raya, Indonesia         1
# Kelapa Gading, Jakarta Raya, Indonesia    1
# Bali, Perifereia Kritis, Greece           1
# Cililitan, Jakarta Raya, Indonesia        1
# Purbalingga, Jawa Tengah, Indonesia       1
# Bali, Zamboanga Del Norte, Philippines    1
# Bali, Hsin-Pei Shih, Taiwan               1
# Name: count, dtype: int64

# %%
# Visualisasi sebaran titik Latitude dan Longitude
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['Longitude'], filtered_df['Latitude'], alpha=0.5, c='red')
plt.title('Distribusi Latitude dan Longitude untuk Jakarta, Bali, dan Purbalingga')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
# Menghitung jumlah event berdasarkan 'Title'
event_counts = filtered_df['Title'].value_counts()

# Menampilkan 10 judul event yang paling sering muncul
event_counts.head(10).plot(kind='bar', color='orange', alpha=0.7)
plt.title('Jumlah Event Berdasarkan Judul di Jakarta, Bali, dan Purbalingga')
plt.xlabel('Judul Event')
plt.ylabel('Jumlah Event')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Menampilkan jumlah event untuk 10 judul teratas
print(event_counts.head(10))
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21360 (\N{CJK UNIFIED IDEOGRAPH-5370}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 23612 (\N{CJK UNIFIED IDEOGRAPH-5C3C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32463 (\N{CJK UNIFIED IDEOGRAPH-7ECF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27982 (\N{CJK UNIFIED IDEOGRAPH-6D4E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26368 (\N{CJK UNIFIED IDEOGRAPH-6700}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26032 (\N{CJK UNIFIED IDEOGRAPH-65B0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36164 (\N{CJK UNIFIED IDEOGRAPH-8D44}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35759 (\N{CJK UNIFIED IDEOGRAPH-8BAF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21160 (\N{CJK UNIFIED IDEOGRAPH-52A8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24577 (\N{CJK UNIFIED IDEOGRAPH-6001}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# Title
# Mary Jane Akan Dipulangkan Ke Filipina Sebelum Natal 2024                                                                                                                        2
# Bali Rutin Dipakai WNA Buronan Masuk Indonesia , Ini Catatan NCB Interpol                                                                                                        2
# Solidaritas untuk Ahmadiyah                                                                                                                                                      2
# Rate Money Changer - Bali Hari ini . domino qiu qiu pro hdi . 76kbet top - apk go win slot                                                                                       2
# 印尼经济最新资讯 _ 印尼经济最新动态 _ 印尼                                                                                                                                                         1
# Fresh pictures of Bali Nine members Matthew Norman and Si - Yi Chen inside jail stoke speculation their release could be imminent                                                1
# Pemandangan . gf777com apk . download apk mt777 apk download - qiu qiu pro versi lama                                                                                            1
# Motif Remaja Bunuh Ayah dan Nenek di Lebak Bulus Masih Ditelusuri Apsifor                                                                                                        1
# 5 singa . DOWNLOAD APK SS88BET Metadata Indeks Tingkatkan kemampuan bermain Mahjong Wins 3 . ACEPH Update Core Mahjong Wins 3 selalu penuh tantangan - qiu qiu pro versi lama    1
# World Bank vows record $100bn support for world poorest countries                                                                                                                1
# Name: count, dtype: int64

# %%
# Mengecek jumlah missing values di kolom-kolom DataFrame
missing_values = filtered_df.isnull().sum()

# Menampilkan hasil
print(missing_values)
# Out:
# Location               0
# LocationResultCount    0
# Latitude               0
# Longitude              0
# URL                    0
# ImageURL               0
# Title                  0
# dtype: int64

# %%
# Menampilkan URL yang sering muncul
url_counts = filtered_df['URL'].value_counts()

# Menampilkan 10 URL paling banyak muncul
print(url_counts.head(10))
# Out:
# URL
# https://nasional.kompas.com/read/2024/12/06/15491461/mary-jane-akan-dipulangkan-ke-filipina-sebelum-natal-2024                       2
# https://bali.jpnn.com/hukum/31652/bali-rutin-dipakai-wna-buronan-masuk-indonesia-ini-catatan-ncb-interpol                            2
# https://regional.kompas.com/read/2024/12/06/11181801/solidaritas-untuk-ahmadiyah                                                     2
# https://www.wmxv1015.com/html/25b5999915.html                                                                                        2
# https://www.chinaz.com/tags/915799.shtml                                                                                             1
# https://www.dailymail.co.uk/news/article-14164597/Bali-Nine-fresh-pictures-Matthew-Norman-Si-Yi-Chen.html                            1
# https://www.710wfnr.com/html/30c0799962.html                                                                                         1
# https://megapolitan.kompas.com/read/2024/12/06/13254361/motif-remaja-bunuh-ayah-dan-nenek-di-lebak-bulus-masih-ditelusuri-apsifor    1
# https://www.710wfnr.com/html/75f5399871.html                                                                                         1
# https://www.geo.tv/latest/578154-world-bank-vows-record-100bn-support-for-worlds-poorest-countries                                   1
# Name: count, dtype: int64

# %%
# Menghitung jumlah ImageURL yang tersedia dan yang hilang
image_url_available = filtered_df['ImageURL'].notna().sum()
image_url_missing = filtered_df['ImageURL'].isna().sum()

# Menampilkan hasil
print(f"Jumlah ImageURL tersedia: {image_url_available}")
print(f"Jumlah ImageURL hilang: {image_url_missing}")
# Out:
# Jumlah ImageURL tersedia: 34
# Jumlah ImageURL hilang: 0

# %%
# Mengganti lokasi yang salah
filtered_df['Location'] = filtered_df['Location'].replace('Bali, Jawa Timur, Indonesia', 'Bali, Indonesia')

# Memeriksa hasil penggantian
corrected_location = filtered_df[filtered_df['Title'] == top_title][['Location']]
print(corrected_location)
# Out:
#                     Location
# 18           Bali, Indonesia
# 106  Peradi, Bali, Indonesia
# <ipython-input-60-9fb7748b4d41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Location'] = filtered_df['Location'].replace('Bali, Jawa Timur, Indonesia', 'Bali, Indonesia')

# %%
# Menampilkan 1 top title berdasarkan jumlah kemunculan
top_title = filtered_df['Title'].value_counts().idxmax()

# Menampilkan lokasi asal (Location) dan URL untuk top title
top_title_data = filtered_df[filtered_df['Title'] == top_title][['Location', 'URL']].head(1)

# Menampilkan hasil
print(f"Top Title: {top_title}")
print(f"Asal Lokasi: {top_title_data['Location'].values[0]}")
print(f"URL: {top_title_data['URL'].values[0]}")
# Out:
# Top Title: Mary Jane Akan Dipulangkan Ke Filipina Sebelum Natal 2024
# Asal Lokasi: Bali, Indonesia
# URL: https://nasional.kompas.com/read/2024/12/06/15491461/mary-jane-akan-dipulangkan-ke-filipina-sebelum-natal-2024
